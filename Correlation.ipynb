# %%
import pandas as pd
import rasterio
from rasterio.plot import show
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load Data
# Load CSV data
fire_data = pd.read_csv("fire_n.csv")
weather_data1 = pd.read_csv("RELATIVE HUMIDITY.csv")
weather_data = pd.read_csv("monthly.csv")
weather_data = pd.read_csv("PointWeatherData.csv")
precipitation_data = pd.read_csv("Precipitation.csv")
precipitation_data2 = pd.read_csv("Monthly_Precipitation_Mt_Kenya_Forest.csv")
landsurface_temp = pd.read_csv("LST.csv")
temp = pd.read_csv("Earth SKIN Temp.csv")
relative_humidity = pd.read_csv("Relative_Humidity.csv")
specific_humidity = pd.read_csv("Specific_Humidity.csv")
soilwetness_surface = pd.read_csv("SoilWetness_Surface.csv")
soilwetness_rootzone = pd.read_csv("SoilWetness_Rootzone.csv")
wind_direction = pd.read_csv("Wind_Direction.csv")
wind_speed = pd.read_csv("Wind_Speed.csv")
yearly_NDVI = pd.read_csv("Yearly_Thresholds_Mt_Kenya_Forest2.csv")
monthly_NDVI = pd.read_csv("Monthly_NDVI_Mt_Kenya_Forest.csv")


GEERain = pd.read_csv('PreciGee.csv')
GEETemp = pd.read_csv('TempGEE.csv')
GEEWsp = pd.read_csv('WspeeGEE.csv')
GEEWdir = pd.read_csv('WdireGEE.csv')

#population_data = pd.read_csv("population_data.csv")

# Load raster data
slope_raster = rasterio.open("Slope_ForestDegree.tif")
aspect_raster = rasterio.open("Aspect_Forest.tif")
#settlement_raster = rasterio.open("settlement.tif")
#population_raster = rasterio.open("population.tif")

# Step 2: Preprocess Data (if necessary)
# Handle missing values, data alignment, etc.

# Step 3: Calculate Correlation
# Combine raster data into numpy arrays
#slope_array = slope_raster.read(1)
#aspect_array = aspect_raster.read(1)
#settlement_array = settlement_raster.read(1)
#population_array = population_raster.read(1)

# Calculate correlation
correlation_df = pd.DataFrame({
    'Fire': fire_data['brightness'],
    'Fire2': fire_data['bright_t31'],
    'Fire3': fire_data['yearly_fire_occurrence'],
    'Fire4': fire_data['monthly_fire_occurrence'],
    #'Fire5': fire_data['frp'],
    'NDVI' : yearly_NDVI['ANN'],
    #'NDVI2' : monthly_NDVI['MeanNDVI'],
    #'Slope': slope_array(),
    #'Aspect': aspect_array.flatten(),
    #'Settlement': settlement_array.flatten(),
    'Weather1': weather_data1['ANN'],
   'Weather': weather_data['ANN'] , # Assuming you have a column with weather data
    #'precipitation_data2' : precipitation_data2["TotalPrecipitation"],
    'precipitation_data' : precipitation_data["ANN"],
    'ESt' : temp['ANN'],
    'landsurface_temp' :  landsurface_temp["ANN"],
    'relative_humidity' : relative_humidity['ANN'],
    'specific_humidity' : specific_humidity["ANN"],
    'soilwetness_surface' :soilwetness_surface["ANN"],
    'soilwetness_rootzone' : soilwetness_rootzone['ANN'],
    'wind_direction' :  wind_direction['ANN'],
    'wind_speed' : wind_speed['ANN']
})

correlation_matrix = correlation_df.corr()

# Step 4: Visualize Correlation
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
sns.pairplot(correlation_df, kind="scatter")
plt.show()
# Out:
# C:\Users\DANIEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Select the columns you want to include in the correlation analysis
correlation_df = pd.DataFrame({
    'Fire3': fire_data['yearly_fire_occurrence'],
    #'Fire4': fire_data['monthly_fire_occurrence'],
    #'Weather1': weather_data1['ANN'],
    'precipitation_data': precipitation_data['ANN'],
    'ESt': temp['ANN'],
    'landsurface_temp': landsurface_temp['ANN'],
    'relative_humidity': relative_humidity['ANN'],
    'specific_humidity': specific_humidity['ANN'],
     'NDVI' : yearly_NDVI['ANN'],
})

# Calculate correlation matrix
correlation_matrix = correlation_df.corr()

# Visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Optionally, visualize pair plots for a more detailed view
sns.pairplot(correlation_df, kind="scatter")
plt.show()
# Out:
# C:\Users\DANIEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd

# %%
GEERain = pd.read_csv('PreciGee.csv')
GEETemp = pd.read_csv('TempGEE.csv')
GEEWsp = pd.read_csv('WspeeGEE.csv')
GEEWdir = pd.read_csv('WdireGEE.csv')

# %%
GEERain 
#GEETemp 
#GEEWsp 
#GEEWdir
# Out:
#     PrecipitationGEE  Year
# 0           2.813108  2000
# 1           4.107178  2001
# 2           5.059427  2002
# 3           4.765912  2003
# 4           3.677437  2004
# 5           3.554748  2005
# 6           5.657109  2006
# 7           4.211887  2007
# 8           3.253020  2008
# 9           3.428764  2009
# 10          4.189164  2010
# 11          4.747806  2011
# 12          4.499848  2012
# 13          3.773508  2013
# 14          3.972228  2014
# 15          4.728693  2015
# 16          3.471495  2016
# 17          3.201598  2017
# 18          6.225876  2018
# 19          5.928176  2019
# 20          6.073959  2020
# 21          3.844113  2021
# 22          3.183991  2022

# %%
import pandas as pd

fire_data =  pd.read_csv('classified_data2.csv')

fire_data
# Out:
#       latitude  longitude  acq_time  YEAR  month  day  ANN  LISA_cluster
# 0       0.2122    37.7333       801  2001      8   11   21             4
# 1       0.1272    37.5555      2023  2001      8   11   21             2
# 2      -0.0990    37.4320       843  2001      9   13   21             2
# 3      -0.1280    37.4616       843  2001      9   13   21             3
# 4      -0.1350    37.4570       843  2001      9   13   21             3
# ...        ...        ...       ...   ...    ...  ...  ...           ...
# 1304    0.1093    37.2822       756  2022      4   29   88             1
# 1305    0.1203    37.4401       811  2022      8   24   88             1
# 1306   -0.4139    36.9572      1141  2022      9   24   88             1
# 1307    0.0992    37.7738       745  2022      9   29   88             1
# 1308    0.1005    37.7649       745  2022      9   29   88             4
#
# [1309 rows x 8 columns]

# %%
import pandas as pd
import rasterio
from rasterio.plot import show
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix


import pandas as pd
import rasterio
from rasterio.plot import show
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


# Load fire data and weather data
fire_data =  pd.read_csv('classified_data2.csv')
Fire = pd.read_csv('annual_ann.csv')
yearly_NDVI = pd.read_csv("Yearly_Thresholds_Mt_Kenya_Forest2.csv")

GEERain = pd.read_csv('PreciGee.csv')
GEETemp = pd.read_csv('TempGEE.csv')
GEEWsp = pd.read_csv('WspeeGEE.csv')
GEEWdir = pd.read_csv('WdireGEE.csv')
GEESpeciHum = pd.read_csv("SpeciHumGEE.csv")
GEERelaHum = pd.read_csv("RelaHumGEE.csv")

# Load raster data
slope_raster = rasterio.open("Slope_ForestDegree.tif")
aspect_raster = rasterio.open("Aspect_Forest.tif")

slope_array = slope_raster.read(1)
aspect_array = aspect_raster.read(1)

# %%
GEESpeciHum
GEERelaHum
# Out:
#       RH_Mean  Year
# 0   78.631498  2001
# 1   78.055884  2002
# 2   76.092406  2003
# 3   77.995076  2004
# 4   76.602958  2005
# 5   78.836962  2006
# 6   78.348606  2007
# 7   76.947238  2008
# 8   74.326405  2009
# 9   78.631076  2010
# 10  76.956580  2011
# 11  76.616651  2012
# 12  78.936138  2013
# 13  78.387366  2014
# 14  76.089669  2015
# 15  78.050452  2016
# 16  75.965163  2017
# 17  79.402339  2018
# 18  78.172790  2019
# 19  80.637302  2020
# 20  77.910933  2021
# 21  75.510806  2022

# %%
print("Length of Fire['ANN']:", len(Fire['ANN']))
print("Length of fire_data['LISA_cluster']:", len(fire_data['LISA_cluster']))
print("Length of GEERain['PrecipitationGEE']:", len(GEERain['PrecipitationGEE']))
print("Length of GEETemp['TempGEE']:", len(GEETemp['TempGEE']))
print("Length of GEEWsp['WindSpeGEE']:", len(GEEWsp['WindSpeGEE']))
print("Length of GEEWdir['WinddireGEE']:", len(GEEWdir['WinddireGEE']))
print("Length of yearly_NDVI['ANN']:", len(yearly_NDVI['ANN']))
print("Length of GEESpeciHum['SpeciHum']:", len(GEESpeciHum['SpeciHum']))
print("Length of GEERelaHum['RH_Mean']:", len(GEERelaHum['RH_Mean']))
print("Length of slope_array:", len(slope_array.flatten()))
print("Length of aspect_array:", len(aspect_array.flatten()))
# Out:
# Length of Fire['ANN']: 22
# Length of fire_data['LISA_cluster']: 1309
# Length of GEERain['PrecipitationGEE']: 23
# Length of GEETemp['TempGEE']: 23
# Length of GEEWsp['WindSpeGEE']: 23
# Length of GEEWdir['WinddireGEE']: 23
# Length of yearly_NDVI['ANN']: 23
# Length of GEESpeciHum['SpeciHum']: 22
# Length of GEERelaHum['RH_Mean']: 22
# Length of slope_array: 5515440
# Length of aspect_array: 5515440

# %%
# Find the minimum length
min_length = min(
    len(Fire['ANN']),
    len(fire_data['LISA_cluster']),
    len(GEERain['PrecipitationGEE']),
    len(GEETemp['TempGEE']),
    len(GEEWsp['WindSpeGEE']),
    len(GEEWdir['WinddireGEE']),
    len(yearly_NDVI['ANN']),
    len(GEESpeciHum['SpeciHum']),
    len(GEERelaHum['RH_Mean']),
    len(slope_array.flatten()),
    len(aspect_array.flatten())
    
)

# Trim arrays to the minimum length
fire_data_trimmed = Fire['ANN'][:min_length]
fire_data_trimmed2 = fire_data['LISA_cluster'][:min_length]
GEERain_trimmed = GEERain['PrecipitationGEE'][:min_length]
GEETemp_trimmed = GEETemp['TempGEE'][:min_length]
GEEWsp_trimmed = GEEWsp['WindSpeGEE'][:min_length]
GEEWdir_trimmed = GEEWdir['WinddireGEE'][:min_length]
yearly_NDVI_trimmed = yearly_NDVI['ANN'][:min_length]
GEESpeciHum_trimmed = GEESpeciHum['SpeciHum'][:min_length]
GEERelaHum_trimmed = GEERelaHum['RH_Mean'][:min_length]
slope_array_trimmed = slope_array.flatten()[:min_length]
aspect_array_trimmed = aspect_array.flatten()[:min_length]

# Now create the DataFrame
correlation_df = pd.DataFrame({
    'Fire': fire_data_trimmed,
    'Fire2': fire_data_trimmed2,
    'GEERain': GEERain_trimmed,
    'GEETemp': GEETemp_trimmed,
    'GEEWsp': GEEWsp_trimmed,
    'GEEWdir': GEEWdir_trimmed,
    'NDVI': yearly_NDVI_trimmed,
    'GEESpeciHum': GEESpeciHum_trimmed,
    'GEERelaHum': GEERelaHum_trimmed,
    'Slope': slope_array_trimmed,
    'Aspect': aspect_array_trimmed,
})





import pandas as pd

# Replace NaN values with the mean of each column
correlation_df = correlation_df.fillna(correlation_df.mean())

# Drop rows with any remaining missing values
df_cleaned = correlation_df.dropna()

# Calculate correlation matrix
correlation_matrix = df_cleaned.corr()

# Print correlation matrix
print(correlation_matrix)




# Calculate correlation matrix
#correlation_matrix = correlation_df.corr()
#print(correlation_matrix)
# Out:
#                  Fire     Fire2   GEERain   GEETemp    GEEWsp   GEEWdir  \
# Fire         1.000000 -0.264112  0.217496 -0.173193  0.143672 -0.078848
# Fire2       -0.264112  1.000000 -0.029977  0.014068  0.305641 -0.476516
# GEERain      0.217496 -0.029977  1.000000  0.262488  0.417651 -0.128894
# GEETemp     -0.173193  0.014068  0.262488  1.000000 -0.043475 -0.357472
# GEEWsp       0.143672  0.305641  0.417651 -0.043475  1.000000 -0.468172
# GEEWdir     -0.078848 -0.476516 -0.128894 -0.357472 -0.468172  1.000000
# NDVI         0.074181  0.147725  0.212809  0.357898  0.028888 -0.359292
# GEESpeciHum -0.148335 -0.012977  0.330675  0.624206  0.026324 -0.003232
# GEERelaHum  -0.357520  0.357821  0.259442  0.440581 -0.014951 -0.057429
# Slope             NaN       NaN       NaN       NaN       NaN       NaN
# Aspect            NaN       NaN       NaN       NaN       NaN       NaN
#
#                  NDVI  GEESpeciHum  GEERelaHum  Slope  Aspect
# ...

# %%
# Visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Optionally, visualize pair plots for a more detailed view
sns.pairplot(correlation_df, kind="scatter")
plt.show()
# Out:
# C:\Users\DANIEL\anaconda3\Lib\site-packages\numpy\lib\histograms.py:810: RuntimeWarning: divide by zero encountered in scalar divide
#   norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
# C:\Users\DANIEL\anaconda3\Lib\site-packages\numpy\lib\histograms.py:838: RuntimeWarning: invalid value encountered in multiply
#   f_indices = _unsigned_subtract(tmp_a, first_edge) * norm
# C:\Users\DANIEL\anaconda3\Lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in cast
#   indices = f_indices.astype(np.intp)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 8
#       5 plt.show()
#       7 # Optionally, visualize pair plots for a more detailed view
# ----> 8 sns.pairplot(correlation_df, kind="scatter")
#       9 plt.show()
#
# ...

# %%
# Select the columns you want to include in the correlation analysis
correlation_df = pd.DataFrame({
   'Fire': fire_data['LISA_cluster'],
    #'FireANN': Fire['ANN'],
    'GEERain': GEERain['PrecipitationGEE'],
    'GEETemp': GEETemp['TempGEE'],
    'GEEWsp': GEEWsp['WindSpeGEE'],
    'GEEWdir': GEEWdir['WinddireGEE'],
     'NDVI' : yearly_NDVI['ANN'],
    'GEESpeciHum' : GEESpeciHum["SpeciHum"],
    'GEERelaHum': GEERelaHum['RH_Mean'],
    'Slope': slope_array.flatten(),
    #'Aspect': aspect_array.flatten(),
      
})

# Calculate correlation matrix
correlation_matrix = correlation_df.corr()

# Visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Optionally, visualize pair plots for a more detailed view
sns.pairplot(correlation_df, kind="scatter")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Select the columns you want to include in the correlation analysis
# ----> 2 correlation_df = pd.DataFrame({
#       3    'Fire': fire_data['LISA_cluster'],
#       4     #'FireANN': Fire['ANN'],
#       5     'GEERain': GEERain['PrecipitationGEE'],
#       6     'GEETemp': GEETemp['TempGEE'],
#       7     'GEEWsp': GEEWsp['WindSpeGEE'],
#       8     'GEEWdir': GEEWdir['WinddireGEE'],
#       9      'NDVI' : yearly_NDVI['ANN'],
#      10     'GEESpeciHum' : GEESpeciHum["SpeciHum"],
#      11     'GEERelaHum': GEERelaHum['RH_Mean'],
#      12     'Slope': slope_array.flatten(),
#      13     #'Aspect': aspect_array.flatten(),
#      14
#      15 })
#      17 # Calculate correlation matrix
#      18 correlation_matrix = correlation_df.corr()
#
# ...

# %%
import pandas as pd

# Assuming all necessary data frames are already loaded

# Select the columns you want to include in the correlation analysis
correlation_df = pd.DataFrame({
    'Fire': fire_data['ANN'],
    'GEERain': GEERain['PrecipitationGEE'],
    'GEETemp': GEETemp['TempGEE'],
    'GEEWsp': GEEWsp['WindSpeGEE'],
    'GEEWdir': GEEWdir['WinddireGEE'],
    'NDVI': yearly_NDVI['ANN'],
})

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()

# Optionally, visualize the correlation matrix using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# Calculate weights based on correlation coefficients
weights = correlation_matrix['Fire'].abs()  # Taking absolute values of correlation coefficients
weights /= weights.sum()  # Normalize weights to sum up to 1

print("Weights based on correlation with 'Fire':")
print(weights)
# Out:
# Weights based on correlation with 'Fire':
# Fire       0.447259
# GEERain    0.109285
# GEETemp    0.180718
# GEEWsp     0.084134
# GEEWdir    0.114470
# NDVI       0.064133
# Name: Fire, dtype: float64

# %%
import pandas as pd

fire_data = pd.read_csv('classified_data2.csv')
fire_data.head()
# Out:
#    latitude  longitude  acq_time  YEAR  month  day  ANN  LISA_cluster
# 0    0.2122    37.7333       801  2001      8   11   21             4
# 1    0.1272    37.5555      2023  2001      8   11   21             2
# 2   -0.0990    37.4320       843  2001      9   13   21             2
# 3   -0.1280    37.4616       843  2001      9   13   21             3
# 4   -0.1350    37.4570       843  2001      9   13   21             3

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Load fire data and weather data
fire_data = fire_data
weather_data = pd.read_csv('Precipitation2.csv')


#weather_data1 = pd.read_csv("RELATIVE HUMIDITY.csv")
#precipitation_data2 = pd.read_csv("Monthly_Precipitation_Mt_Kenya_Forest.csv")
Relaivehumidity = pd.read_csv('RELATIVE HUMIDITY.csv')
landsurface_temp = pd.read_csv("LST2.csv")
temp = pd.read_csv("Earth SKIN Temp2.csv")
relative_humidity = pd.read_csv("Relative_Humidity2.csv")
specific_humidity = pd.read_csv("Specific_Humidity2.csv")
soilwetness_surface = pd.read_csv("SoilWetness_Surface2.csv")
soilwetness_rootzone = pd.read_csv("SoilWetness_Rootzone2.csv")
wind_direction = pd.read_csv("Wind_Direction2.csv")
wind_speed = pd.read_csv("Wind_Speed2.csv")
yearly_NDVI = pd.read_csv("Yearly_Thresholds_Mt_Kenya_Forest22.csv")
#monthly_NDVI = pd.read_csv("Monthly_NDVI_Mt_Kenya_Forest.csv")
region = pd.read_csv('WEATHERREGION.csv')


# Merge datasets based on common columns

merged_data = pd.merge(fire_data, weather_data, on=['YEAR'])
#merged_data = pd.merge(merged_data, landsurface_temp, on=['YEAR'])
#merged_data = pd.merge(merged_data, temp, on=['YEAR'])
#merged_data = pd.merge(merged_data, relative_humidity, on=['YEAR']) 
#merged_data = pd.merge(merged_data, specific_humidity, on=['YEAR'])
#merged_data = pd.merge(merged_data, yearly_NDVI, on=['YEAR'])
merged_data = pd.merge(merged_data, soilwetness_surface, on=['YEAR']) 
merged_data = pd.merge(merged_data, soilwetness_rootzone, on=['YEAR']) 
merged_data = pd.merge(merged_data, wind_direction, on=['YEAR']) 
merged_data = pd.merge(merged_data, wind_speed, on=['YEAR']) 


merged_data.head()
# Out:
#    latitude  longitude  acq_time  YEAR  month  day  ANN  LISA_cluster  \
# 0    0.2122    37.7333       801  2001      8   11   21             4
# 1    0.2122    37.7333       801  2001      8   11   21             4
# 2    0.2122    37.7333       801  2001      8   11   21             4
# 3    0.2122    37.7333       801  2001      8   11   21             4
# 4    0.2122    37.7333       801  2001      8   11   21             4
#
#    Precipitation  Wetsurface  Wetroot  Wdirection  Wspeed
# 0           5.27        0.48     0.48      133.88     6.1
# 1           5.27        0.48     0.48      133.88     6.1
# 2           5.27        0.48     0.48      133.88     6.1
# 3           5.27        0.48     0.48      133.88     6.1
# 4           5.27        0.48     0.48      133.88     6.1

# %%
import matplotlib.pyplot as plt
import rasterio
from rasterio.plot import show
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Calculate correlation
correlation_df = pd.DataFrame({
    'Fire': fire_data['ANN'],
    'NDVI' : yearly_NDVI['NDVI'],
    #'Slope': slope_array(),
    #'Aspect': aspect_array.flatten(),
    #'Settlement': settlement_array.flatten(),
   'Weather': weather_data['Precipitation'] , # Assuming you have a column with weather data
    'landsurface_temp' :  landsurface_temp["LST"],
    'temp' :  temp["TS"],
    'relative_humidity' : relative_humidity['RelaHum'],
    'specific_humidity' : specific_humidity["Spechum"],
    'soilwetness_surface' :soilwetness_surface["Wetsurface"],
    'soilwetness_rootzone' : soilwetness_rootzone['Wetroot'],
    'wind_direction' :  wind_direction['Wdirection'],
    'wind_speed' : wind_speed['Wspeed'],
    #"Region" : region['ANN'],
    #'Relaivehumidity':Relaivehumidity['ANN']
})

correlation_matrix = correlation_df.corr()

# Step 4: Visualize Correlation
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.savefig("Correlation1", dpi =600, bbox_inches = 'tight')
plt.show()


sns.pairplot(correlation_df, kind="scatter")
plt.savefig("Correlationpairplot", dpi =600, bbox_inches = 'tight')
plt.show()=+++
# Out:
# C:\Users\DANIEL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
